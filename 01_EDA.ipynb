# %% [markdown]
# # EDA for Insurance Risk Analytics
# Student: Blen Asefa
# Date: 25 May 2026

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('data/insurance_data.csv')
print(df.head())
print("\nData shape:", df.shape)

# %% [markdown]
# ## 2. Overall Loss Ratio

# %%
total_claims = df['TotalClaims'].sum()
total_premium = df['TotalPremium'].sum()
loss_ratio = total_claims / total_premium
print(f"Overall Loss Ratio: {loss_ratio:.4f}")

# %% [markdown]
# ## 3. Loss Ratio by Province

# %%
province_loss = df.groupby('Province').apply(
    lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum(),
    include_groups=False
)
province_loss.sort_values().plot(kind='bar', color='teal')
plt.title('Loss Ratio by Province')
plt.ylabel('Loss Ratio')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Premium Distribution by Gender

# %%
sns.violinplot(data=df, x='Gender', y='TotalPremium')
plt.title('Premium Distribution by Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Claim Severity by Vehicle Type

# %%
claims = df[df['TotalClaims'] > 0]
top_types = claims['VehicleType'].value_counts().head(6).index
plt.figure(figsize=(10,6))
sns.boxplot(data=claims[claims['VehicleType'].isin(top_types)], x='VehicleType', y='TotalClaims')
plt.xticks(rotation=45)
plt.title('Claim Severity by Vehicle Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Answers to Guiding Questions
#
# - Overall Loss Ratio: 0.5282
# - Loss ratio by province (highest to lowest): Somali (0.612), Oromia (0.537), Tigray (0.526), Addis Ababa (0.522), Amhara (0.478)
# - Loss ratio by vehicle type: Luxury vehicles have the highest claim severity, suggesting higher loss ratio.
# - Loss ratio by gender: No meaningful difference (mean premiums: female 2489.52, male 2486.66).
# - Outliers in TotalClaims? Yes – many zero claims, but extreme positive claims exist; will be handled by subsetting and log transform.
# - Temporal trends: To be analysed in final report (add time series plot).
# - Highest claim amounts by vehicle type: Luxury > SUV > Hatchback > Sedan.
